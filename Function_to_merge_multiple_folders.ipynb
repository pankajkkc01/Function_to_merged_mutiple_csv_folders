# %%
base_folder = '/content/drive/MyDrive/data_foulders/data/PR'
output_file = '/content/drive/MyDrive/data_folders/new_file2.csv'

# %%
import pandas as pd
import os

def merge_csv_folders(base_folder, output_file):
    all_files = []

    # Walk through each folder
    for root, _, files in os.walk(base_folder):
        for file in files:
            if file.endswith('.csv'):
                file_path = os.path.join(root, file)
                all_files.append(file_path)

    # List to hold DataFrames
    dataframes = []

    # Read each file and append DataFrame to the list
    for file in all_files:
        df = pd.read_csv(file)
        dataframes.append(df)

    # Concatenate all DataFrames
    combined_df = pd.concat(dataframes, ignore_index=True)

    # Save the combined DataFrame to a single CSV file
    combined_df.to_csv(output_file, index=False)

# Call the function
merge_csv_folders(base_folder, output_file)

# %%
pd.read_csv('/content/drive/MyDrive/data_folders/new_file2.csv')
# Out:
#            Date         PR
# 0    2019-07-26  70.662366
# 1    2019-07-27  61.164194
# 2    2019-07-28  68.921739
# 3    2019-07-29  76.294480
# 4    2019-07-30  78.962515
# ..          ...        ...
# 977  2021-10-24  71.197289
# 978  2021-10-25  84.049634
# 979  2021-10-26  79.218055
# 980  2021-10-27  72.385925
# 981  2021-10-28  70.581150
#
# [982 rows x 2 columns]
