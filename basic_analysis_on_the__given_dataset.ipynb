# %%
import pandas as pd
import numpy as np
import  seaborn as sns

# %%
df1=pd.read_csv('/content/drive/MyDrive/data_folders/new_file.csv')
df2=pd.read_csv('/content/drive/MyDrive/data_folders/new_file2.csv')

# %%
df1.head()
# Out:
#          Date       GHI
# 0  2020-03-22  6.300492
# 1  2020-03-23  5.735908
# 2  2020-03-24  5.065017
# 3  2020-03-25  5.750350
# 4  2020-03-26  5.283633

# %%
merged_df = pd.merge(df1, df2, on='Date', how='outer')

# %%
output_file = '/content/drive/MyDrive/data_folders/merged_data.csv' # Add a filename to the path
merged_df.to_csv(output_file, index=False)

# %%
merged_df.head()
# Out:
#          Date       GHI         PR
# 0  2020-03-22  6.300492  72.198136
# 1  2020-03-23  5.735908  77.861827
# 2  2020-03-24  5.065017  77.598430
# 3  2020-03-25  5.750350  66.465840
# 4  2020-03-26  5.283633  65.642955

# %%
merged_df.shape
# Out:
# (982, 3)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    982 non-null    object
#  1   GHI     982 non-null    float64
#  2   PR      982 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 23.1+ KB

# %%
merged_df.isnull().sum()
# Out:
# Date    0
# GHI     0
# PR      0
# dtype: int64

# %%
merged_df.describe()
# Out:
#               GHI          PR
# count  982.000000  982.000000
# mean     4.629912   72.714933
# std      1.024159    7.294222
# min      1.413825   60.023886
# 25%      4.021665   66.309422
# 50%      4.737796   72.947945
# 75%      5.312283   79.111721
# max      6.947317   84.980120

# %%
sns.pairplot(merged_df)

# %%
df_subset=merged_df[['GHI','PR']]

# %%
sns.heatmap(df_subset.corr())
# Out:
# <Axes: >

# %%
print(df_subset.corr())
# hence both of the variales are almost not releted
# Out:
#           GHI        PR
# GHI  1.000000  0.058234
# PR   0.058234  1.000000
